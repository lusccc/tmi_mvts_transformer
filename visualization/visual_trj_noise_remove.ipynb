# %%
cd ..

# %%
import matplotlib.pyplot as plt
import numpy as np
from data_preprocess.utils import interp_single_seg

# %%
noise_fs=np.load('data/SHL_features/noise_multi_feature_segs.npy', allow_pickle=True)
clean_fs=np.load('data/SHL_features/clean_multi_feature_segs.npy', allow_pickle=True)

# %%
idx=3
ne=noise_fs[idx]
cn=clean_fs[idx]
interp_cn=interp_single_seg
plt.plot(ne[0], label='noise')
plt.plot(cn[0], label='clean')
plt.legend()
plt.show()

# %%
pwd
# Out:
# '/mnt/kx/Users/lsc/Desktop/tmi_mvts_transformer'
